# %% [markdown]
# ### Opening metocean data from opendap database
#
# [https://maritim.bmkg.go.id/opendap/](https://maritim.bmkg.go.id/opendap/)

# %%
import xarray as xr

# %%
dset = xr.open_dataset("https://renderofs:AksesTerbatas2303!!!@maritim.bmkg.go.id/opendap/ww3gfs/2025/03/w3g_hires_20250310_0000.nc")
dset
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 881, lat: 481, time: 81)
# Coordinates:
#   * lon      (lon) float64 90.0 90.06 90.12 90.19 ... 144.8 144.9 144.9 145.0
#   * lat      (lat) float64 -15.0 -14.94 -14.88 -14.81 ... 14.81 14.88 14.94 15.0
#   * time     (time) datetime64[ns] 2025-03-10 2025-03-10T03:00:00 ... 2025-03-20
# Data variables: (12/17)
#     dtn      (time) float64 ...
#     hs       (time, lat, lon) float32 ...
#     lm       (time, lat, lon) float32 ...
#     t01      (time, lat, lon) float32 ...
#     dir      (time, lat, lon) float32 ...
#     phs00    (time, lat, lon) float32 ...
#     ...       ...
#     pdi00    (time, lat, lon) float32 ...
#     pdi01    (time, lat, lon) float32 ...
#     pdi02    (time, lat, lon) float32 ...
#     uwnd     (time, lat, lon) float32 ...
#     vwnd     (time, lat, lon) float32 ...
#     hmax     (time, lat, lon) float32 ...
